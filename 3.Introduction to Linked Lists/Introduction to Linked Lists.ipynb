# %% [markdown]
# ![image.png](attachment:f29b87f1-1623-4d03-84ea-e8230abe5e9d.png)

# %% [markdown]
# ### Define function to count no. of nodes in a LL
#
# ![image.png](attachment:b224f823-f06f-4d63-b58f-94bf197c492f.png)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %%
# Define function to count no. of nodes in a LL

def count_nodes(head):
    if head.data != None:
        count = 1
    else: 
        count = 0

    temp = head.next
    while temp != None:
        count += 1
        temp = temp.next

    return count

# %%
nodeA = Node(6)
nodeB = Node(3)
nodeC = Node(4)
nodeD = Node(2)
nodeE = Node(1)

nodeA.next = nodeB
nodeB.next = nodeC
nodeC.next = nodeD
nodeD.next = nodeE

print("This linked list's length is: (should print 5)")
print(count_nodes(nodeA))
# Out:
# This linked list's length is: (should print 5)
# 5

# %%
# A doubly LL had one pointer pointing to previous node
# so it can traverse both next and prev

# Node for doubly linked List

class NodeDoubly:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
